# %% [markdown]
# <center><img src="https://github.com/insaid2018/Term-1/blob/master/Images/INSAID_Full%20Logo.png?raw=true" width="240" height="100" /></center>

# %% [markdown]
# ---
# # **Table of Contents**
# ---
#
# **1.** [**Introduction**](#Section1)<br>
# **2.** [**Problem Statement**](#Section2)<br>
# **3.** [**Installing & Importing Libraries**](#Section3)<br>
#   - **3.1** [**Installing Libraries**](#Section31)
#   - **3.2** [**Upgrading Libraries**](#Section32)
#   - **3.3** [**Importing Libraries**](#Section33)
#
# **4.** [**Data Acquisition & Description**](#Section4)<br>
#   - **4.1** [**Data Description**](#Section41)
#   - **4.2** [**Data Information**](#Section42)
#
# **5.** [**Data Pre-processing**](#Section5)<br>
#   - **5.1** [**Handling of Missing Data**](#Section51)
#   - **5.2** [**Handling of Redundant Data**](#Section52)
#   - **5.3** [**Handling of Inconsistent Data**](#Section53)
#   - **5.4** [**Handling of Outliers**](#Section54)
#
# **6.** [**Data Cleaning**](#Section6)<br>
#
# **7.** [**Data Post-Profiling**](#Section7)<br>
#
#
# **8.** [**Exploratory Data Analysis**](#Section8)<br>
#   - **8.1** [**Number of runs scored by all batsmans in their ODI matches?**](#Section81)
#   - **8.2** [**Total No. of runs scored by batsman from various reasons?**](#Section82)
#   - **8.3** [**What is the density distribution of Avarage of the players?**](#Section83)
#   - **8.4** [**What is total Avarage per density of players?**](#Section84)
#   - **8.5** [**Total number of players from different Regions?**](#Section85)
#   - **8.6** [**Total number of 100s from players from different Regions?**](#Section86)
#   - **8.7** [**Who are the top 20 run getter batsmans in ODI?**](#Section87)
#   - **8.8** [**Calculate duration of all the players**](#Section88)
#   - **8.9** [**Show the stats of all the players**](#Section89)
#   - **8.10** [**Who is most number of times Not out in an inning?**](#Section810)
#   - **8.11** [**Who having highest avg in ODI cricket?**](#Section811)
#   - **8.12** [**What is the contribution of top 3 regions among all in terms of players?**](#Section812)
#   - **8.13** [**What is the proportion of each players from different Region?**](#Section813)
#   - **8.14** [**Find out highest score by player in ODI.**](#Section814)
#
# **9.** [**Summarization**](#Section9)<br>
#       - **9.1** [**Conclusion**](#Section91)<br>

# %% [markdown]
# ---
# <a name = Section1></a>
# # **1. Introduction**
# ---
#
# - Cricket is a very popular sport in **India** as well as in other cricket playing countries. Information about a cricket match is provided using a scorecard. The analysis of such scorecards generate information important for players, team management, selection boards and other interested parties since they will lead to better judgment about players, their strengths and weaknesses, and performance as a team. This information is in the form of statistical data that changes with every cricket match. The World Wide Web is the most commonly used and possibly the largest information system available at present. An Internet based information system using a database as its back-end can effectively manage the cricket data and dynamically present up-to-date statistical information to all its users. The design and development of such an information system for One-Day International (ODI) cricket is described in this paper. Input of the system is mainly in the form of cricket scorecards.
#
#
#
#
#
#
#
#
#
# - Presentation of statistical information for series, country, match, team statistics, batting records, bowling records, fielding, wicket keeping, player profile and all round performance to the users, and the capability to answer frequently asked questions about cricket are the output of the system.
#
#
#
#
#
#
#
#
# <center><img width=60% src="https://wallpapercave.com/wp/wp3990000.jpg"></center>

# %% [markdown]
# ---
# <a name = Section2></a>
# # **2. Problem Statement**
# ---
#
# - ODI matches are played for a quota of 50 overs per country and they are either played in daytime or day and night.
#
#
# - ODI matches are more popular than Test matches since there is excitement and the match is over in the same day.
#
#
# - ODI cricket is also known as instant cricket since there is always a match result within a period of seven to eight hours unless weather prevents
#
#
# - Find out **most number of runs** in ODI.
#
#
# - Find out **highest batting average** in ODI.
#
#
# - Find out **highest score** scored by the batsman in ODI.
#
#
# - Find out **density distribution of Average of the players** scored by the batsman in ODI.
#
#
# - Find out **Total number of players from different Regions** scored by the batsman in ODI.
#
#
# - Find out **Calculate duration of all the players** scored by the batsman in ODI.
#
#
# - **Show the stats of all the players** scored by the batsman in ODI.
#
#
# - Find out **Total number of 100s from players from different Regions** scored by the batsman in ODI.
#
#
#
#
#
# <center><img width=60% src="https://raw.githubusercontent.com/insaid2018/PGPDSAI/main/03%20Term%203%20-%20EDA%20%26%20Data%20Storytelling/03%20Module%203/img/04%20mental-health.png"></center>

# %% [markdown]
# ---
# <a name = Section3></a>
# # **3. Installing & Importing Libraries**
# ---

# %% [markdown]
# <a name = Section31></a>
# ### **3.1 Installing Libraries**

# %%
import sys
# !{sys.executable} -m pip install pandas_profiling

# %% [markdown]
# <a name = Section32></a>
# ### **3.2 Upgrading Libraries**
#
# - **After upgrading** the libraries, you need to **restart the runtime** to make the libraries in sync.
#
# - Make sure not to execute the cell above (3.1) and below (3.2) again after restarting the runtime.

# %%
# !pip install -q --upgrade pandas_profiling
# !pip install -q --upgrade yellowbrick

# %% [markdown]
# <a name = Section33></a>
# ### **3.3 Importing Libraries**

# %%
import numpy as np
#-------------------------------------------------------------------------------------------------------------------------------
import pandas as pd                                                 # Importing for panel data analysis
pd.set_option('display.max_columns', None)                          # Unfolding hidden features if the cardinality is high
pd.set_option('display.max_colwidth', None)                         # Unfolding the max feature width for better clearity
pd.set_option('display.max_rows', None)                             # Unfolding hidden data points if the cardinality is high
pd.set_option('mode.chained_assignment', None)                      # Removing restriction over chained assignments operations
pd.set_option('display.float_format', lambda x: '%.2f' % x)         # To suppress scientific notation over exponential values
#-------------------------------------------------------------------------------------------------------------------------------
from collections import Counter                                     # For counting hashable objects
#-------------------------------------------------------------------------------------------------------------------------------
import matplotlib.pyplot as plt                                     # Importing pyplot interface using matplotlib
import plotly.graph_objs as go                                      # For Plotly interfaced graphs
import seaborn as sns                                               # Importin seaborm library for interactive visualization
# %matplotlib inline
#-------------------------------------------------------------------------------------------------------------------------------
import warnings                                                     # Importing warning to disable runtime warnings
warnings.filterwarnings("ignore")                                   # Warnings will appear only once

# %% [markdown]
# ---
# <a name = Section4></a>
# # **4. Data Acquisition & Description**
# ---
#
# - This dataset is obtained from a survey in 2020.
#
# - The dataset obtain the batting performance of batsman across world cricket.This data includes all batting records of players.
#
#
# | Records | Features | Dataset Size |
# | :-- | :-- | :-- |
# | 2500 | 15 | 166.77 kB|
#
#
# | Id | Features | Description |
# | :-- | :--| :--|
# |01|**Unnamed: 0**|Sr. No.|
# |02|**Player**|Player name and for which country he played or playing.|
# |03|**Span**|Cricketing carrier.|
# |04|**Mat**|No. of matches he played.|
# |05|**Inns**|No. of innings he played.|
# |06|**NO**|Not outs in no. of matches.|
# |07|**Runs**|Total no. of runs he scrored in ODI matches.|
# |08|**HS**|Highest score of the players.|
# |09|**Ave**|Total batting average of the player.|
# |10|**BF**|Total no. of Ball faced by batsman to scrored runs.|
# |11|**SR**|Batting strike rate|
# |12|**100**|Total no. of centuries.|
# |13|**50**|Total no. of fifties.|
# |14|**0**|Total no. of Ducks.|
# |15|**Unnamed: 13**|NaN.|

# %%
ODI_data = pd.read_csv('ODI data.csv')

ODI_data
# Out:
#       Unnamed: 0                          Player       Span  Mat Inns  NO  \
# 0              0            SR Tendulkar (INDIA)  1989-2012  463  452  41
# 1              1     KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41
# 2              2            RT Ponting (AUS/ICC)  1995-2012  375  365  39
# 3              3         ST Jayasuriya (Asia/SL)  1989-2011  445  433  18
# 4              4      DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39
# 5              5       Inzamam-ul-Haq (Asia/PAK)  1991-2007  378  350  53
# 6              6                 V Kohli (INDIA)  2008-2019  242  233  39
# 7              7          JH Kallis (Afr/ICC/SA)  1996-2014  328  314  53
# 8              8         SC Ganguly (Asia/INDIA)  1992-2007  311  300  23
# 9              9       R Dravid (Asia/ICC/INDIA)  1996-2011  344  318  40
# 10            10           MS Dhoni (Asia/INDIA)  2004-2019  350  297  84
# 11            11               CH Gayle (ICC/WI)  1999-2019  301  294  17
# ...

# %%
ODI_data.head()
# Out:
#    Unnamed: 0                       Player       Span  Mat Inns  NO   Runs  \
# 0           0         SR Tendulkar (INDIA)  1989-2012  463  452  41  18426
# 1           1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234
# 2           2         RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704
# 3           3      ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430
# 4           4   DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650
#
#      HS    Ave     BF     SR 100  50   0  Unnamed: 13
# 0  200*  44.83  21367  86.23  49  96  20          NaN
# 1   169  41.98  18048  78.86  25  93  15          NaN
# 2   164  42.03  17046  80.39  30  82  20          NaN
# 3   189  32.36  14725   91.2  28  68  34          NaN
# 4   144  33.37  16020  78.96  19  77  28          NaN

# %%
100*(ODI_data.shape[0]-ODI_data.count())/ODI_data.shape[0]
# Out:
# Unnamed: 0      0.00
# Player          0.00
# Span            0.00
# Mat             0.00
# Inns            0.00
# NO              0.00
# Runs            0.00
# HS              0.00
# Ave             0.00
# BF              0.00
# SR              0.00
# 100             0.00
# 50              0.00
# 0               0.00
# Unnamed: 13   100.00
# dtype: float64

# %% [markdown]
# <a name = Section41></a>
# ### **4.1 Data Description**
#
# - In this section we will get **information about the data** and see some observations.

# %%
ODI_data.describe(include='all')
# Out:
#         Unnamed: 0                 Player       Span     Mat  Inns    NO  \
# count      2500.00                   2500       2500 2500.00  2500  2500
# unique         NaN                   2499        566     NaN   218    61
# top            NaN  Raqibul Hasan (BDESH)  2019-2019     NaN     1     0
# freq           NaN                      2        101     NaN   281   736
# mean         24.50                    NaN        NaN   37.16   NaN   NaN
# std          14.43                    NaN        NaN   58.89   NaN   NaN
# min           0.00                    NaN        NaN    1.00   NaN   NaN
# 25%          12.00                    NaN        NaN    4.00   NaN   NaN
# 50%          24.50                    NaN        NaN   13.00   NaN   NaN
# 75%          37.00                    NaN        NaN   43.00   NaN   NaN
# max          49.00                    NaN        NaN  463.00   NaN   NaN
#
#         Runs    HS   Ave    BF    SR   100    50     0  Unnamed: 13
# ...

# %%
ODI_data['Span'].value_counts()
# Out:
# 2019-2019    101
# 2018-2019     37
# 2017-2019     35
# 2003-2003     33
# 2018-2018     32
# 2004-2004     32
# 2016-2019     31
# 2008-2008     30
# 2014-2019     27
# 2015-2019     26
# 1999-1999     24
# 1975-1975     24
# 2009-2009     22
# 2009-2019     22
# 1996-1996     22
# 2011-2011     22
# 1979-1979     21
# 2013-2019     21
# 2007-2007     21
# 2006-2007     21
# 2006-2006     21
# 2016-2016     18
# 2011-2019     17
# 2010-2019     17
# 2006-2009     16
# 2010-2010     16
# 1995-1995     15
# 2013-2013     15
# 2017-2017     15
# 2015-2015     14
# 2012-2019     14
# 1994-1994     14
# 1997-1997     13
# 2006-2010     13
# 2014-2018     12
# 2008-2019     12
# 1978-1978     12
# 2016-2018     12
# 2015-2018     11
# 2000-2000     11
# 1998-1998     11
# 2014-2015     11
# 1994-1996     11
# 2007-2008     11
# 1986-1986     11
# 2010-2011     11
# 1983-1983     11
# 2002-2002     11
# 2008-2009     10
# 2014-2016     10
# 2008-2014     10
# 1990-1990     10
# ...

# %% [markdown]
# **Observations:**
#
# - The **Player names** are **absurd**.
#
# - **Unnamed: 0** and **Unnamed: 13** both columns are not shows proper values.

# %% [markdown]
# <a name = Section42></a>
# ### **4.2 Data Information**
#
# - In this section we will see the **information about the types of features**.

# %%
ODI_data.info(verbose=True, memory_usage='deep', null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   2500 non-null   int64
#  1   Player       2500 non-null   object
#  2   Span         2500 non-null   object
#  3   Mat          2500 non-null   int64
#  4   Inns         2500 non-null   object
#  5   NO           2500 non-null   object
#  6   Runs         2500 non-null   object
#  7   HS           2500 non-null   object
#  8   Ave          2500 non-null   object
#  9   BF           2500 non-null   object
#  10  SR           2500 non-null   object
#  11  100          2500 non-null   object
#  12  50           2500 non-null   object
#  13  0            2500 non-null   object
#  14  Unnamed: 13  0 non-null      float64
# dtypes: float64(1), int64(2), object(12)
# memory usage: 1.8 MB

# %% [markdown]
# **Observations:**
#
# - **Unnamed: 0** and **Unnamed: 13** both columns are not shows proper values.
#
# - Data set does not shows proper **data types**.

# %% [markdown]
# <a name = Section5></a>
#
# ---
# # **5. Data Pre-Processing**
# ---

# %% [markdown]
# <a name = Section51></a>
# ### **5.1 Handling of Missing Data**
#
# - In this section, we will identify missing data and check the proportion of it and take appropriate measures.

# %%
null_frame = pd.DataFrame(index = ODI_data.columns.values)

# %%
null_frame['Null Frequency'] = ODI_data.isnull().sum().values
null_frame
# Out:
#              Null Frequency
# Unnamed: 0                0
# Player                    0
# Span                      0
# Mat                       0
# Inns                      0
# NO                        0
# Runs                      0
# HS                        0
# Ave                       0
# BF                        0
# SR                        0
# 100                       0
# 50                        0
# 0                         0
# Unnamed: 13            2500

# %%
percent = ODI_data.isnull().sum().values/ODI_data.shape[0]

# %%
null_frame['Missing %age'] = np.round(percent, decimals = 4) * 100
null_frame
# Out:
#              Null Frequency  Missing %age
# Unnamed: 0                0          0.00
# Player                    0          0.00
# Span                      0          0.00
# Mat                       0          0.00
# Inns                      0          0.00
# NO                        0          0.00
# Runs                      0          0.00
# HS                        0          0.00
# Ave                       0          0.00
# BF                        0          0.00
# SR                        0          0.00
# 100                       0          0.00
# 50                        0          0.00
# 0                         0          0.00
# Unnamed: 13            2500        100.00

# %% [markdown]
# **Observations:**
#
# - We can observe that following features are found to have missing values along with the proportions:
#
# |Feature|Object Type|Missing Proportion|Solution|
# |:--:|:--:|:--:|:--|
# |Unnamed: 13|float64|100%|Drop the feature.|

# %% [markdown]
# **Performing Operations**

# %%
ODI_data.drop(['Unnamed: 0', 'Unnamed: 13'], axis=1, inplace=True)

ODI_data.head()
# Out:
#                         Player       Span  Mat Inns  NO   Runs    HS    Ave  \
# 0         SR Tendulkar (INDIA)  1989-2012  463  452  41  18426  200*  44.83
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234   169  41.98
# 2         RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704   164  42.03
# 3      ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430   189  32.36
# 4   DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650   144  33.37
#
#       BF     SR 100  50   0
# 0  21367  86.23  49  96  20
# 1  18048  78.86  25  93  15
# 2  17046  80.39  30  82  20
# 3  14725   91.2  28  68  34
# 4  16020  78.96  19  77  28

# %% [markdown]
# - Let's verify the integrity of null values again.

# %%
null_frame = pd.DataFrame(index = ODI_data.columns.values)
null_frame['Null Frequency'] = ODI_data.isnull().sum().values
percent = ODI_data.isnull().sum().values/ODI_data.shape[0]
null_frame['Missing %age'] = np.round(percent, decimals = 4) * 100
null_frame
# Out:
#         Null Frequency  Missing %age
# Player               0          0.00
# Span                 0          0.00
# Mat                  0          0.00
# Inns                 0          0.00
# NO                   0          0.00
# Runs                 0          0.00
# HS                   0          0.00
# Ave                  0          0.00
# BF                   0          0.00
# SR                   0          0.00
# 100                  0          0.00
# 50                   0          0.00
# 0                    0          0.00

# %% [markdown]
# <a name = Section52></a>
# ### **5.2 Handling of Redundant Data**
#
# - In this section, we will identify redundant data and check the proportion of it and take appropriate measures.

# %%
ODI_data.duplicated().any()
# Out:
# False

# %%
print('Contains Duplicate Rows?', ODI_data.duplicated().any())
# Out:
# Contains Duplicate Rows? False

# %% [markdown]
# <a name = Section53></a>
# ### **5.3 Handling of Inconsistent Data**
#
# - In this section, we will **identify inconsistency** in data and and then **take appropriate measures**.
#
# - Additionally, we can observe that some features are having data of different format such as Player.

# %%
ODI_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  2500 non-null   object
#  1   Span    2500 non-null   object
#  2   Mat     2500 non-null   int64
#  3   Inns    2500 non-null   object
#  4   NO      2500 non-null   object
#  5   Runs    2500 non-null   object
#  6   HS      2500 non-null   object
#  7   Ave     2500 non-null   object
#  8   BF      2500 non-null   object
#  9   SR      2500 non-null   object
#  10  100     2500 non-null   object
#  11  50      2500 non-null   object
#  12  0       2500 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 254.0+ KB

# %% [markdown]
# ### **5.4 Handling of Outliers**
#
# - Additionally, we can observe that some features are having data of different format such as Player.
#
# - we observed that **Inns**, **NO**, **Runs**, **HS**, **Avg**, **BF**, **SR**, **100**, **50**, **0** feature was **incorrectly indentified** data types as Object, so, we will rectify it

# %%
ODI_data.head()
# Out:
#                         Player       Span  Mat Inns  NO   Runs    HS    Ave  \
# 0         SR Tendulkar (INDIA)  1989-2012  463  452  41  18426  200*  44.83
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234   169  41.98
# 2         RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704   164  42.03
# 3      ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430   189  32.36
# 4   DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650   144  33.37
#
#       BF     SR 100  50   0
# 0  21367  86.23  49  96  20
# 1  18048  78.86  25  93  15
# 2  17046  80.39  30  82  20
# 3  14725   91.2  28  68  34
# 4  16020  78.96  19  77  28

# %%
#Spilt the 'Player' column

ODI_data['Player'].str.split()
# Out:
# 0                  [SR, Tendulkar, (INDIA)]
# 1           [KC, Sangakkara, (Asia/ICC/SL)]
# 2                  [RT, Ponting, (AUS/ICC)]
# 3               [ST, Jayasuriya, (Asia/SL)]
# 4            [DPMD, Jayawardene, (Asia/SL)]
# 5              [Inzamam-ul-Haq, (Asia/PAK)]
# 6                       [V, Kohli, (INDIA)]
# 7                [JH, Kallis, (Afr/ICC/SA)]
# 8               [SC, Ganguly, (Asia/INDIA)]
# 9             [R, Dravid, (Asia/ICC/INDIA)]
# 10                [MS, Dhoni, (Asia/INDIA)]
# 11                    [CH, Gayle, (ICC/WI)]
# 12                     [BC, Lara, (ICC/WI)]
# 13                      [TM, Dilshan, (SL)]
# 14           [Mohammad, Yousuf, (Asia/PAK)]
# 15               [AC, Gilchrist, (AUS/ICC)]
# 16             [AB, de, Villiers, (Afr/SA)]
# 17                 [M, Azharuddin, (INDIA)]
# 18                    [PA, de, Silva, (SL)]
# 19                    [RG, Sharma, (INDIA)]
# 20                    [Saeed, Anwar, (PAK)]
# ...

# %%
#Add new column to the ODI_data which is 'Region' where the players are played or playing for.

ODI_data['Region']=ODI_data['Player'].str.split().str[2]

ODI_data.head()
# Out:
#                         Player       Span  Mat Inns  NO   Runs    HS    Ave  \
# 0         SR Tendulkar (INDIA)  1989-2012  463  452  41  18426  200*  44.83
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234   169  41.98
# 2         RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704   164  42.03
# 3      ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430   189  32.36
# 4   DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650   144  33.37
#
#       BF     SR 100  50   0         Region
# 0  21367  86.23  49  96  20        (INDIA)
# 1  18048  78.86  25  93  15  (Asia/ICC/SL)
# 2  17046  80.39  30  82  20      (AUS/ICC)
# 3  14725   91.2  28  68  34      (Asia/SL)
# 4  16020  78.96  19  77  28      (Asia/SL)

# %%
#Split the 'Player' column so that player names are saparated in name and surnames, for that add two new colums

ODI_data['Player Name2']=ODI_data['Player'].str.split().str[1]

ODI_data.head()
# Out:
#                         Player       Span  Mat Inns  NO   Runs    HS    Ave  \
# 0         SR Tendulkar (INDIA)  1989-2012  463  452  41  18426  200*  44.83
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234   169  41.98
# 2         RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704   164  42.03
# 3      ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430   189  32.36
# 4   DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650   144  33.37
#
#       BF     SR 100  50   0         Region Player Name2
# 0  21367  86.23  49  96  20        (INDIA)    Tendulkar
# 1  18048  78.86  25  93  15  (Asia/ICC/SL)   Sangakkara
# 2  17046  80.39  30  82  20      (AUS/ICC)      Ponting
# 3  14725   91.2  28  68  34      (Asia/SL)   Jayasuriya
# 4  16020  78.96  19  77  28      (Asia/SL)  Jayawardene

# %%
ODI_data['Player Name1']=ODI_data['Player'].str.split().str[0]
ODI_data.head()
# Out:
#                         Player       Span  Mat Inns  NO   Runs    HS    Ave  \
# 0         SR Tendulkar (INDIA)  1989-2012  463  452  41  18426  200*  44.83
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234   169  41.98
# 2         RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704   164  42.03
# 3      ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430   189  32.36
# 4   DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650   144  33.37
#
#       BF     SR 100  50   0         Region Player Name2 Player Name1
# 0  21367  86.23  49  96  20        (INDIA)    Tendulkar           SR
# 1  18048  78.86  25  93  15  (Asia/ICC/SL)   Sangakkara           KC
# 2  17046  80.39  30  82  20      (AUS/ICC)      Ponting           RT
# 3  14725   91.2  28  68  34      (Asia/SL)   Jayasuriya           ST
# 4  16020  78.96  19  77  28      (Asia/SL)  Jayawardene         DPMD

# %%
#Merge or add two columns 'Player Name1' & 'Player Name1' and save in the new column called Player Name

ODI_data['Player Name']=ODI_data['Player Name1'] + ODI_data['Player Name2']

ODI_data.head()
# Out:
#                         Player       Span  Mat Inns  NO   Runs    HS    Ave  \
# 0         SR Tendulkar (INDIA)  1989-2012  463  452  41  18426  200*  44.83
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234   169  41.98
# 2         RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704   164  42.03
# 3      ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430   189  32.36
# 4   DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650   144  33.37
#
#       BF     SR 100  50   0         Region Player Name2 Player Name1  \
# 0  21367  86.23  49  96  20        (INDIA)    Tendulkar           SR
# 1  18048  78.86  25  93  15  (Asia/ICC/SL)   Sangakkara           KC
# 2  17046  80.39  30  82  20      (AUS/ICC)      Ponting           RT
# 3  14725   91.2  28  68  34      (Asia/SL)   Jayasuriya           ST
# 4  16020  78.96  19  77  28      (Asia/SL)  Jayawardene         DPMD
#
#        Player Name
# 0      SRTendulkar
# 1     KCSangakkara
# 2        RTPonting
# ...

# %%
#Now drop the useless or repeated columns

ODI_data.drop(['Player', 'Player Name1', 'Player Name2'], axis=1, inplace=True)

ODI_data.head()
# Out:
#         Span  Mat Inns  NO   Runs    HS    Ave     BF     SR 100  50   0  \
# 0  1989-2012  463  452  41  18426  200*  44.83  21367  86.23  49  96  20
# 1  2000-2015  404  380  41  14234   169  41.98  18048  78.86  25  93  15
# 2  1995-2012  375  365  39  13704   164  42.03  17046  80.39  30  82  20
# 3  1989-2011  445  433  18  13430   189  32.36  14725   91.2  28  68  34
# 4  1998-2015  448  418  39  12650   144  33.37  16020  78.96  19  77  28
#
#           Region      Player Name
# 0        (INDIA)      SRTendulkar
# 1  (Asia/ICC/SL)     KCSangakkara
# 2      (AUS/ICC)        RTPonting
# 3      (Asia/SL)     STJayasuriya
# 4      (Asia/SL)  DPMDJayawardene

# %%
#Arrange the data set.

ODI_data =ODI_data [['Player Name', 'Region', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR', '100', '50', '0' ]]

ODI_data.head()
# Out:
#        Player Name         Region       Span  Mat Inns  NO   Runs    HS  \
# 0      SRTendulkar        (INDIA)  1989-2012  463  452  41  18426  200*
# 1     KCSangakkara  (Asia/ICC/SL)  2000-2015  404  380  41  14234   169
# 2        RTPonting      (AUS/ICC)  1995-2012  375  365  39  13704   164
# 3     STJayasuriya      (Asia/SL)  1989-2011  445  433  18  13430   189
# 4  DPMDJayawardene      (Asia/SL)  1998-2015  448  418  39  12650   144
#
#      Ave     BF     SR 100  50   0
# 0  44.83  21367  86.23  49  96  20
# 1  41.98  18048  78.86  25  93  15
# 2  42.03  17046  80.39  30  82  20
# 3  32.36  14725   91.2  28  68  34
# 4  33.37  16020  78.96  19  77  28

# %% [markdown]
# **Observation:**
#
# - Now that we have successfully cleansed our data we are good to go with exploring our data and finding insights.

# %% [markdown]
# **Replace non numeric values into numeric values to rectify incorrectly indentified data types as Object.**

# %%
#Replace non numeric values into numeric values to rectify incorrectly indentified data types as Object.

ODI_data['Runs']=ODI_data['Runs'].replace('-','0')
ODI_data['HS']=ODI_data['HS'].str.replace('*','')
ODI_data['Ave']=ODI_data['Ave'].replace('-','0')
ODI_data['SR']=ODI_data['SR'].replace('-','0')
ODI_data['Inns']=ODI_data['Inns'].replace('-','0')
ODI_data['NO']=ODI_data['NO'].replace('-','0')
ODI_data['HS']=ODI_data['HS'].replace('-','0')
ODI_data['BF']=ODI_data['BF'].replace('-','0')
ODI_data['100']=ODI_data['100'].replace('-','0')
ODI_data['50']=ODI_data['50'].replace('-','0')
ODI_data['0']=ODI_data['0'].replace('-','0')

# %%
#Change the data type

ODI_data['Runs']=ODI_data['Runs'].astype('int')
ODI_data['Inns']=ODI_data['Inns'].astype('int')
ODI_data['NO']=ODI_data['NO'].astype('int')
ODI_data['BF']=ODI_data['BF'].astype('int')
ODI_data['100']=ODI_data['100'].astype('int')
ODI_data['50']=ODI_data['50'].astype('int')
ODI_data['0']=ODI_data['0'].astype('int')
ODI_data['Ave']=ODI_data['Ave'].astype('float')
ODI_data['HS']=ODI_data['HS'].astype('int')
ODI_data['SR']=ODI_data['SR'].astype('float')
ODI_data
# Out:
#                  Player Name            Region       Span  Mat  Inns  NO  \
# 0                SRTendulkar           (INDIA)  1989-2012  463   452  41
# 1               KCSangakkara     (Asia/ICC/SL)  2000-2015  404   380  41
# 2                  RTPonting         (AUS/ICC)  1995-2012  375   365  39
# 3               STJayasuriya         (Asia/SL)  1989-2011  445   433  18
# 4            DPMDJayawardene         (Asia/SL)  1998-2015  448   418  39
# 5   Inzamam-ul-Haq(Asia/PAK)             (ENG)  1991-2007  378   350  53
# 6                     VKohli           (INDIA)  2008-2019  242   233  39
# 7                   JHKallis      (Afr/ICC/SA)  1996-2014  328   314  53
# 8                  SCGanguly      (Asia/INDIA)  1992-2007  311   300  23
# 9                    RDravid  (Asia/ICC/INDIA)  1996-2011  344   318  40
# 10                   MSDhoni      (Asia/INDIA)  2004-2019  350   297  84
# 11                   CHGayle          (ICC/WI)  1999-2019  301   294  17
# ...

# %%
#Solve the incorrectly indentified data types as Object to correct data type of the data.
ODI_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Player Name  50 non-null     object
#  1   Region       50 non-null     object
#  2   Span         50 non-null     object
#  3   Mat          50 non-null     int64
#  4   Inns         50 non-null     int32
#  5   NO           50 non-null     int32
#  6   Runs         50 non-null     int32
#  7   HS           50 non-null     int32
#  8   Ave          50 non-null     float64
#  9   BF           50 non-null     int32
#  10  SR           50 non-null     float64
#  11  100          50 non-null     int32
#  12  50           50 non-null     int32
#  13  0            50 non-null     int32
#  14  Start Year   50 non-null     int32
#  15  Last Year    50 non-null     int32
#  16  Duration     50 non-null     int32
# dtypes: float64(2), int32(11), int64(1), object(3)
# memory usage: 4.6+ KB

# %% [markdown]
# <a name = Section6></a>
#
# ---
# # **6. Data Cleaning**
# ---
#
# - In this section, we will perform the **cleaning** operations over the features using information from the previous section.
#
# - We will simply **drop** the **rows** that contain **duplicate** values.

# %%
ODI_data['Region'].value_counts()
# Out:
# (ENG)               239
# (AUS)               211
# (PAK)               198
# (INDIA)             197
# (WI)                188
# (NZ)                183
# (SL)                163
# (ZIM)               132
# (BDESH)             112
# (SA)                 94
# (UAE)                80
# (CAN)                80
# (SCOT)               67
# (IRE)                53
# (NL)                 52
# (KENYA)              46
# (HKG)                40
# (AFG)                38
# (BMUDA)              35
# (USA)                27
# (PNG)                23
# (NAM)                22
# (NEPAL)              19
# (Afr/SA)             14
# (EAf)                13
# (OMAN)               12
# Silva                12
# (Asia/INDIA)          7
# (Asia/SL)             5
# (AUS/ICC)             5
# jnr                   5
# der                   5
# (Afr/ZIM)             4
# (USA/WI)              3
# (Afr/KENYA)           3
# (ENG/IRE)             3
# (Asia/BDESH)          3
# (ENG/ICC)             3
# ...

# %%
null_frame = pd.DataFrame(index = ODI_data.columns.values)

# %%
null_frame['Null Frequency'] = ODI_data.isnull().sum().values
null_frame
# Out:
#              Null Frequency
# Player Name               0
# Region                   22
# Span                      0
# Mat                       0
# Inns                      0
# NO                        0
# Runs                      0
# HS                        0
# Ave                       0
# BF                        0
# SR                        0
# 100                       0
# 50                        0
# 0                         0

# %%
percent = ODI_data.isnull().sum().values/ODI_data.shape[0]

# %%
null_frame['Missing %age'] = np.round(percent, decimals = 4) * 100
null_frame
# Out:
#              Null Frequency  Missing %age
# Player Name               0          0.00
# Region                   22          0.88
# Span                      0          0.00
# Mat                       0          0.00
# Inns                      0          0.00
# NO                        0          0.00
# Runs                      0          0.00
# HS                        0          0.00
# Ave                       0          0.00
# BF                        0          0.00
# SR                        0          0.00
# 100                       0          0.00
# 50                        0          0.00
# 0                         0          0.00

# %% [markdown]
# **Observations:**
#
# - We can observe that following features are found to have missing values along with the proportions:
#
# |Feature|Object Type|Missing Proportion|Solution|
# |:--:|:--:|:--:|:--|
# |Region|Object|0.88%|Replace with mode.|

# %%
ODI_data['Region'] = ODI_data['Region'].replace(np.nan, ODI_data['Region'].mode()[0])

# %% [markdown]
# - Let's verify the integrity of null values again.

# %%
null_frame = pd.DataFrame(index = ODI_data.columns.values)
null_frame['Null Frequency'] = ODI_data.isnull().sum().values
percent = ODI_data.isnull().sum().values/ODI_data.shape[0]
null_frame['Missing %age'] = np.round(percent, decimals = 4) * 100
null_frame
# Out:
#              Null Frequency  Missing %age
# Player Name               0          0.00
# Region                    0          0.00
# Span                      0          0.00
# Mat                       0          0.00
# Inns                      0          0.00
# NO                        0          0.00
# Runs                      0          0.00
# HS                        0          0.00
# Ave                       0          0.00
# BF                        0          0.00
# SR                        0          0.00
# 100                       0          0.00
# 50                        0          0.00
# 0                         0          0.00

# %%
#Find out is their any duplicate data in the data set.

ODI_data.duplicated().any()
# Out:
# False

# %%
print('Contains Duplicate Rows?', ODI_data.duplicated().any())
# Out:
# Contains Duplicate Rows? False

# %% [markdown]
# <a name = Section7></a>
#
# ---
# # **7. Data Post-Profiling**
# ---
#
# - In this section, we will observe the changes after performing data pre-processing, if present.

# %% [markdown]
# **Observations**:
#
# - There are **no missing values** in the dataset.
#
# - There are **no duplicate values** in the dataset.
#
# - **Description** feature shows **high cardinality**.

# %% [markdown]
# <a name = Section8></a>
#
# ---
# # **8. Exploratory Data Analysis**

# %%
#Taking sample from the original dataset and assume that sample as our data set for simple the operations.

ODI_data=ODI_data.head(50)
ODI_data
# Out:
#                  Player Name            Region       Span  Mat  Inns  NO  \
# 0                SRTendulkar           (INDIA)  1989-2012  463   452  41
# 1               KCSangakkara     (Asia/ICC/SL)  2000-2015  404   380  41
# 2                  RTPonting         (AUS/ICC)  1995-2012  375   365  39
# 3               STJayasuriya         (Asia/SL)  1989-2011  445   433  18
# 4            DPMDJayawardene         (Asia/SL)  1998-2015  448   418  39
# 5   Inzamam-ul-Haq(Asia/PAK)             (ENG)  1991-2007  378   350  53
# 6                     VKohli           (INDIA)  2008-2019  242   233  39
# 7                   JHKallis      (Afr/ICC/SA)  1996-2014  328   314  53
# 8                  SCGanguly      (Asia/INDIA)  1992-2007  311   300  23
# 9                    RDravid  (Asia/ICC/INDIA)  1996-2011  344   318  40
# 10                   MSDhoni      (Asia/INDIA)  2004-2019  350   297  84
# 11                   CHGayle          (ICC/WI)  1999-2019  301   294  17
# ...

# %% [markdown]
# ### Write your questions here:

# %%
ODI_data.columns
# Out:
# Index(['Player Name', 'Region', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS',
#        'Ave', 'BF', 'SR', '100', '50', '0'],
#       dtype='object')

# %%
print('Data Shape:', ODI_data.shape)
# Out:
# Data Shape: (50, 14)

# %% [markdown]
# <a name = Section81></a>
# **<h4>Question:** Q1. Number of runs scored by all batsmans in their ODI matches.</h4>

# %%
# Extracting labels of Category in a list
x_value = ODI_data['Player Name'].value_counts().index.to_list()

# Extracting proportion values for each category
y_value = ODI_data['Runs'].value_counts().index.to_list()

# Display the extracted values
print('x-axis values:', x_value)
print('y-axis values', y_value)
# Out:
# x-axis values: ['SRTendulkar', 'EJGMorgan', 'VSehwag', 'HMAmla', 'HHGibbs', 'ShahidAfridi', 'SPFleming', 'MJClarke', 'SRWaugh', 'ShoaibMalik', 'ARanatunga', 'JavedMiandad', 'YounisKhan', 'KCSangakkara', 'SaleemMalik', 'NJAstle', 'GCSmith', 'WUTharanga', 'MGBevan', 'TamimIqbal', 'GKirsten', 'AFlower', 'IVARichards', 'MJGuptill', 'LRPLTaylor', 'MEWaugh', 'MSAtapattu', 'DLHaynes', 'RTPonting', 'STJayasuriya', 'DPMDJayawardene', 'Inzamam-ul-Haq(Asia/PAK)', 'VKohli', 'JHKallis', 'SCGanguly', 'RDravid', 'MSDhoni', 'CHGayle', 'BCLara', 'TMDilshan', 'MohammadYousuf', 'ACGilchrist', 'ABde', 'MAzharuddin', 'PAde', 'RGSharma', 'SaeedAnwar', 'SChanderpaul', 'YuvrajSingh', 'MohammadHafeez']
# ...

# %% [markdown]
# <a name = Section82></a>
# **<h4>Question:** Q2. Total No. of runs scored by batsman from various reasons.</h4>

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(data=ODI_data,x='Region',y='Runs')
plt.xticks(rotation=90, fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(xlabel='Runs', fontsize=14)
plt.ylabel(ylabel='Region', fontsize=14)
plt.title(label='Total No. of runs scored per Reason', fontsize=16)
plt.show()

# %% [markdown]
# <a name = Section83></a>
# **<h4>Question:** Q3. What is the density distribution of Avarage of the players?</h4>

# %%
ODI_data['Ave'].describe()
# Out:
# count   50.00
# mean    39.73
# std      6.66
# min     23.57
# 25%     35.12
# 50%     39.24
# 75%     42.02
# max     59.84
# Name: Ave, dtype: float64

# %% [markdown]
# **Observations:**
#
# - Highest avg that is **59.84** in the ODI.
# - Lowest avg that is **23.57** in the ODI.

# %% [markdown]
# <a name = Section84></a>
# **<h4>Question:** Q4.What is total Avarage per density of players?</h4>

# %%
plt.figure(figsize=(10,8))
sns.distplot(ODI_data['Ave'])
plt.xticks(rotation=90, fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(xlabel='Ave', fontsize=14)
plt.ylabel(ylabel='Density', fontsize=14)
plt.title(label='Total Avarage per density of players', fontsize=16)
plt.show()

# %% [markdown]
# <a name = Section85></a>
# **<h4>Question:** Q5. Total number of players from different Regions.</h4>

# %%
figure = plt.figure(figsize=[15, 7])

(100* ODI_data['Region'].value_counts()/ODI_data.shape[0]).plot.bar()

plt.xticks(rotation=90, size=12)
plt.yticks(ticks=np.arange(0, 15, 2), size=12)

plt.xlabel(xlabel='Region', size=14)
plt.ylabel(ylabel='Total number of players', size=14)
plt.title(label='Total number of players per Region', size=16)

plt.show()

# %% [markdown]
# <a name = Section86></a>
# **<h4>Question:** Q6. Total number of 100s from players from different Regions?</h4>

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(data=ODI_data,x='Region',y='100')
plt.xticks(rotation=90, fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(xlabel='Region', fontsize=14)
plt.ylabel(ylabel='Total no. of 100s', fontsize=14)
plt.title(label='Total No. of 100 scored by batsman from different Reason', fontsize=16)
plt.show()

# %%
ODI_data.columns
# Out:
# Index(['Player Name', 'Region', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS',
#        'Ave', 'BF', 'SR', '100', '50', '0'],
#       dtype='object')

# %% [markdown]
# <a name = Section87></a>
# **<h4>Question:** Q7. Who are the top 20 run getter batsmans in ODI?</h4>

# %%
# Initiate an empty figure of 15 X 7
figure = plt.figure(figsize=[15, 7])

# Plot the coutplot figure concerning Player Name and Runs
sns.violinplot(x="Player Name", y="Runs", palette="gnuplot", data=ODI_data.head(20))

# Add some cosmetics
plt.title(label='Top 20 run scored by batsman in ODI', size=16)
plt.xlabel(xlabel="Player Name", size=14)
plt.ylabel(ylabel="Runs", size=14)
plt.xticks(rotation=90, size=12)
plt.yticks(size=12)
plt.grid(b=True)

# Display the figure
plt.show()

# %% [markdown]
# <a name = Section88></a>
# **<h4>Question:** Q8. Calculate duration of all the players</h4>

# %%
ODI_data[['Start Year', 'Last Year']] = ODI_data['Span'].str.split('-', n=1, expand=True)
ODI_data
# Out:
#                  Player Name            Region       Span  Mat  Inns  NO  \
# 0                SRTendulkar           (INDIA)  1989-2012  463   452  41
# 1               KCSangakkara     (Asia/ICC/SL)  2000-2015  404   380  41
# 2                  RTPonting         (AUS/ICC)  1995-2012  375   365  39
# 3               STJayasuriya         (Asia/SL)  1989-2011  445   433  18
# 4            DPMDJayawardene         (Asia/SL)  1998-2015  448   418  39
# 5   Inzamam-ul-Haq(Asia/PAK)             (ENG)  1991-2007  378   350  53
# 6                     VKohli           (INDIA)  2008-2019  242   233  39
# 7                   JHKallis      (Afr/ICC/SA)  1996-2014  328   314  53
# 8                  SCGanguly      (Asia/INDIA)  1992-2007  311   300  23
# 9                    RDravid  (Asia/ICC/INDIA)  1996-2011  344   318  40
# 10                   MSDhoni      (Asia/INDIA)  2004-2019  350   297  84
# 11                   CHGayle          (ICC/WI)  1999-2019  301   294  17
# ...

# %%
ODI_data['Start Year']=ODI_data['Start Year'].astype('int')
ODI_data['Last Year']=ODI_data['Last Year'].astype('int')

# %%
ODI_data['Duration']= ODI_data['Last Year'] - ODI_data['Start Year']
ODI_data
# Out:
#                  Player Name            Region       Span  Mat  Inns  NO  \
# 0                SRTendulkar           (INDIA)  1989-2012  463   452  41
# 1               KCSangakkara     (Asia/ICC/SL)  2000-2015  404   380  41
# 2                  RTPonting         (AUS/ICC)  1995-2012  375   365  39
# 3               STJayasuriya         (Asia/SL)  1989-2011  445   433  18
# 4            DPMDJayawardene         (Asia/SL)  1998-2015  448   418  39
# 5   Inzamam-ul-Haq(Asia/PAK)             (ENG)  1991-2007  378   350  53
# 6                     VKohli           (INDIA)  2008-2019  242   233  39
# 7                   JHKallis      (Afr/ICC/SA)  1996-2014  328   314  53
# 8                  SCGanguly      (Asia/INDIA)  1992-2007  311   300  23
# 9                    RDravid  (Asia/ICC/INDIA)  1996-2011  344   318  40
# 10                   MSDhoni      (Asia/INDIA)  2004-2019  350   297  84
# 11                   CHGayle          (ICC/WI)  1999-2019  301   294  17
# ...

# %%
# Initiate an empty figure of 15 X 7
figure = plt.figure(figsize=[15, 7])

plt.figure(figsize=(20,10))
plt.plot(ODI_data.groupby('Player Name').agg({'Duration' : 'mean'}).sort_values('Duration'))
# Add some cosmetics
plt.title(label='Total duration of players in ODI', size=16)
plt.xlabel(xlabel="Player Name", size=14)
plt.ylabel(ylabel="Duration in Years", size=14)
plt.xticks(rotation=90, size=12)
plt.yticks(size=12)
plt.grid(b=True)

# Display the figure
plt.show()

# %% [markdown]
# <a name = Section89></a>
# **<h4>Question:** Q9. Show the stats of all the players</h4>

# %%
ODI_data.groupby('Player Name').mean().sort_values('Mat')
# Out:
#                             Mat   Inns    NO     Runs   Ave       BF   100  \
# Player Name
# MJGuptill                179.00 176.00 19.00  6626.00 42.20  7586.00 16.00
# HMAmla                   181.00 178.00 14.00  8113.00 49.46  9178.00 27.00
# GKirsten                 185.00 185.00 19.00  6798.00 40.95  9436.00 13.00
# IVARichards              187.00 167.00 24.00  6721.00 47.00  7451.00 11.00
# GCSmith                  197.00 194.00 10.00  6989.00 37.98  8648.00 10.00
# TamimIqbal               204.00 202.00  8.00  6892.00 35.52  8865.00 11.00
# AFlower                  213.00 208.00 16.00  6786.00 35.34  9097.00  4.00
# MohammadHafeez           218.00 216.00 15.00  6614.00 32.90  8633.00 11.00
# RGSharma                 221.00 214.00 32.00  8944.00 49.14 10063.00 28.00
# NJAstle                  223.00 217.00 14.00  7090.00 34.92  9760.00 16.00
# LRPLTaylor               228.00 212.00 37.00  8376.00 47.86 10091.00 20.00
# ...

# %% [markdown]
# <a name = Section810></a>
# **<h4>Question:** Q10. Who is most number of times Not out in an inning?</h4>

# %%
plt.figure(figsize=(20,10))
plt.plot(ODI_data.groupby('Player Name').agg({'NO' : 'mean'}).sort_values('NO'))
# Add some cosmetics
plt.title(label='Not out in ODI', size=16)
plt.xlabel(xlabel="Player Name", size=14)
plt.ylabel(ylabel="Not out innings", size=14)
plt.xticks(rotation=90, size=12)
plt.yticks(size=12)
plt.grid(b=True)

# Display the figure
plt.show()

# %% [markdown]
# **Observations:**
#
# - MS Dhoni is most number of time Not out in an inning that is 84 times in the ODI so far.
# - Tamim Iqbal is least number of time Not out in an inning that is 8 times in the ODI so far.

# %% [markdown]
# <a name = Section811></a>
# **<h4>Question:** Q11. Who having highest avg in ODI cricket?</h4>

# %%
plt.figure(figsize=(20,10))
plt.plot(ODI_data.groupby('Player Name').agg({'Ave' : 'mean'}).sort_values('Ave'))
# Add some cosmetics
plt.title(label='Highest avarage of player in ODI', size=16)
plt.xlabel(xlabel="Player Name", size=14)
plt.ylabel(ylabel="Avarage", size=14)
plt.xticks(rotation=90, size=12)
plt.yticks(size=12)
plt.grid(b=True)

# Display the figure
plt.show()

# %% [markdown]
# **Observations:**
#
# - **Virat Kohli** have highest avg that is 59.84 in this data set.
# - **Shahid Afridi** have lowest avg that is 23.57 in this data set.

# %% [markdown]
# <a name = Section812></a>
# **<h4>Question:** Q12.What is the contribution of top 3 regions among all in terms of players?</h4>

# %%
# Create a new dataframe based on top 3 Region
Region = pd.concat([ODI_data.loc[ODI_data['Region']=='(INDIA)'], 
                       ODI_data.loc[ODI_data['Region']=='(PAK)'], 
                       ODI_data.loc[ODI_data['Region']=='(AUS)']]).reset_index(drop=True)

# Display the results
print('There number of players that exist from top 3 regions are: ', Region.shape[0])
print('Their proportion from total players surveyed is ', np.round(Region.shape[0]/ODI_data.shape[0], decimals=2))
# Out:
# There number of players that exist from top 3 regions are:  14
# Their proportion from total players surveyed is  0.28

# %% [markdown]
# <a name = Section813></a>
# **<h4>Question:** Q13.What is the proportion of each players from different Region?</h4>

# %%
# Creating a custom figure size of 10 X 10 inches
figure = plt.figure(figsize=[12, 12])

# Using magic of pandas pie() function
ODI_data['Region'].value_counts().plot(kind = 'pie', autopct='%3.1f%%')

plt.ylabel(ylabel='Region', size=14)
plt.title(label='Donut Plot showing the proportion of each players from different Region', size=16)
plt.show()

# %% [markdown]
# <a name = Section814></a>
# **<h4>Question:** Q14.Find out highest score by player in ODI.</h4>

# %%
ODI_data['HS'].describe()
# Out:
# count    50.00
# mean    160.82
# std      31.81
# min     102.00
# 25%     141.00
# 50%     153.00
# 75%     179.75
# max     264.00
# Name: HS, dtype: float64

# %% [markdown]
# **Observations:**
#
# - **Rohit Sharma** scored **264** runs in an inning which is highest score by any batsman in the world in ODI cricket.

# %% [markdown]
# ---
# <a name = Section9></a>
# # **9. Summarization**
# ---
# ---
# <a name = Section91></a>
# - **<h4>Conclusion</h4>**
#
#    - ODI matches are played for a quota of 50 overs per country and they are either played in daytime or day and night.
#
#    - ODI matches are more popular than Test matches since there is excitement and the match is over in the same day.
#
#    - ODI cricket is also known as instant cricket since there is always a match result within a period of seven to eight hours unless weather prevents
#
#    - **Sachin Tendulkar** is the highest run getter in the ODI with over 18000 runs.
#
#    - **Virat Kohli** have highest avg that is **59.84** in this data set.
#    - **Shahid Afridi** have lowest avg that is **23.57** in this data set.
#
#    - MS Dhoni is most number of time Not out in an inning that is 84 times in the ODI so far.
#    - Tamim Iqbal is least number of time Not out in an inning that is 8 times in the ODI so far.
#    - **Sachin Tendulkar** played **23 years** cricket for India, Which is highest durtion of any player in the world.
#    - **Rohit Sharma** scored **264** runs in an inning which is highest score by any batsman in the world in ODI cricket.
